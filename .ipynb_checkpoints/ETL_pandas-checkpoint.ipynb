# %%
# !pip install pymongo (to run)

import pymongo
import pandas as pd
from pymongo import MongoClient

# %%
client = MongoClient()
db = client.Project6
collection = db.project
data = pd.DataFrame(list(collection.find()))

# %%
data
# Out:
#                            _id         id       acronym  status  \
# 0     63cfea2a40978a139c439701  101043356      PROGRESS  SIGNED
# 1     63cfea2a40978a139c439702  101100999         SCOPE  SIGNED
# 2     63cfea2a40978a139c439703  101057802      e-IRGSP7  SIGNED
# 3     63cfea2a40978a139c439704  190100375      EOinTime  SIGNED
# 4     63cfea2a40978a139c439705  101073222   BosomShield  SIGNED
# ...                        ...        ...           ...     ...
# 5245  63cfea2c40978a139c43ab7e  101087030       MOLIPEC  SIGNED
# 5246  63cfea2c40978a139c43ab7f  101087007      eBio-hub  SIGNED
# 5247  63cfea2c40978a139c43ab80  101087471     Boost4Bio  SIGNED
# 5248  63cfea2c40978a139c43ab81  101060646  SNETPFORWARD  SIGNED
# 5249  63cfea2c40978a139c43ab82  101087318   ACCELERATOR  SIGNED
#
#                                                   title  startDate    endDate  \
# 0     Reading provenance from ubiquitous quartz:  un... 2023-01-01 2027-12-31
# ...

# %%
client = MongoClient()
db = client.Project6
collection = db.OCDE_ind
df_OCDE_ind = pd.DataFrame(list(collection.find()))

# %%
df_OCDE_ind
# Out:
#                              _id LOCATION  Country   VAR  \
# 0       63e121cd40b08a245c9b2844      DEU  Germany  PROD
# 1       63e121cd40b08a245c9b2845      DEU  Germany  PROD
# 2       63e121cd40b08a245c9b2846      DEU  Germany  PROD
# 3       63e121cd40b08a245c9b2847      DEU  Germany  PROD
# 4       63e121cd40b08a245c9b2848      DEU  Germany  PROD
# ...                          ...      ...      ...   ...
# 999995  63e1233740b08a245caa6a7f      IRL  Ireland  INTP
# 999996  63e1233740b08a245caa6a80      IRL  Ireland  INTP
# 999997  63e1233740b08a245caa6a81      SWE   Sweden  PROD
# 999998  63e1233740b08a245caa6a82      SWE   Sweden  PROD
# 999999  63e1233740b08a245caa6a83      SWE   Sweden  PROD
#
#                                          Variable     IND  \
# 0       Production (gross output), current prices  D01T99
# 1       Production (gross output), current prices  D01T99
# 2       Production (gross output), current prices  D01T99
# ...
